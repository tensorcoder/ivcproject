# %%
from resnet50 import resNet50 as RN50

rn = RN50()

# predicted_label = rn.test_classification(r"C:\Users\pc1\Documents\IVC\Image_and_Vision\catdog\catdog\CATS\cat_1_4.png")
# print(predicted_label)

# %%
rn.train()
# Out:
# Found 810 files belonging to 2 classes.
# Found 788 files belonging to 2 classes.
# train ds :
# <BatchDataset shapes: ((None, 224, 224, 3), (None, 1)), types: (tf.float32, tf.float32)>
#  val ds :
# <BatchDataset shapes: ((None, 224, 224, 3), (None, 1)), types: (tf.float32, tf.float32)>
# train ds :
# <PrefetchDataset shapes: ((None, 224, 224, 3), (None, 1)), types: (tf.float32, tf.float32)>
#  val ds :
# <PrefetchDataset shapes: ((None, 224, 224, 3), (None, 1)), types: (tf.float32, tf.float32)>
# (2, 224, 224, 3)
# (2, 1)
# WARNING:tensorflow:AutoGraph could not transform <bound method KerasLayer.call of <tensorflow_hub.keras_layer.KerasLayer object at 0x0000019122B163A0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# ...
